# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import os

# %%
input_folders = [
    "/content/drive/MyDrive/Courses/CIS531/Term_Project/olympics/qa_data/results/",
    "/content/drive/MyDrive/Courses/CIS531/Term_Project/olympics/qa_data/"
]
output_file = "/content/drive/MyDrive/Courses/CIS531/Term_Project/olympics/qa_data/combined_qa_data.csv"

# %%
# Getting all the datasets into dfs, from both of my input folders :)

qa_dataframes = []

for input_folder in input_folders:
    qa_files = [f for f in os.listdir(input_folder) if f.endswith('.csv')]
    for qa_file in qa_files:
        file_path = os.path.join(input_folder, qa_file)
        try:
            df = pd.read_csv(file_path)
            qa_dataframes.append(df)
            print(f"Successfully read {qa_file} from {input_folder}")
        except Exception as e:
            print(f"Failed to read {qa_file} from {input_folder}: {e}")
# Out:
# Successfully read artistic_gymnastics_qa.csv from /content/drive/MyDrive/Courses/CIS531/Term_Project/olympics/qa_data/results/
# Successfully read 3x3_basketball_qa.csv from /content/drive/MyDrive/Courses/CIS531/Term_Project/olympics/qa_data/results/
# Successfully read archery_qa.csv from /content/drive/MyDrive/Courses/CIS531/Term_Project/olympics/qa_data/results/
# Successfully read artistic_swimming_qa.csv from /content/drive/MyDrive/Courses/CIS531/Term_Project/olympics/qa_data/results/
# Successfully read Badminton_processed_qa.csv from /content/drive/MyDrive/Courses/CIS531/Term_Project/olympics/qa_data/results/
# Successfully read Basketball_processed_qa.csv from /content/drive/MyDrive/Courses/CIS531/Term_Project/olympics/qa_data/results/
# Successfully read Cycling_Mountain_Bike_processed_qa.csv from /content/drive/MyDrive/Courses/CIS531/Term_Project/olympics/qa_data/results/
# ...

# %%
combined_df = pd.concat(qa_dataframes, ignore_index=True) # putting them all together :)
combined_df.to_csv(output_file, index=False) # and saving!
print(f"QA data saved to {output_file} boiii")
# Out:
# QA data saved to /content/drive/MyDrive/Courses/CIS531/Term_Project/olympics/qa_data/combined_qa_data.csv boiii
